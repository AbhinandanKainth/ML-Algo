# %% [markdown]
# <a href="https://colab.research.google.com/github/kainthcool/ML-Algo/blob/master/Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
data = pd.read_csv('./dataset/Admission_Predict_Ver1.1.csv')

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
data[data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Serial No., GRE Score, TOEFL Score, University Rating, SOP, LOR , CGPA, Research, Chance of Admit ]
# Index: []

# %%
del data['Serial No.']

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# 5          330          115                  5  4.5   3.0  9.34         1
# 6          321          109                  3  3.0   4.0  8.20         1
# 7          308          101                  2  3.0   4.0  7.90         0
# 8          302          102                  1  2.0   1.5  8.00         0
# 9          323          108                  3  3.5   3.0  8.60         0
# 10         325          106                  3  3.5   4.0  8.40         1
# 11         327          111                  4  4.0   4.5  9.00         1
# ...

# %%
#to drop null values if any
data = data.dropna()

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# 5          330          115                  5  4.5   3.0  9.34         1
# 6          321          109                  3  3.0   4.0  8.20         1
# 7          308          101                  2  3.0   4.0  7.90         0
# 8          302          102                  1  2.0   1.5  8.00         0
# 9          323          108                  3  3.5   3.0  8.60         0
# 10         325          106                  3  3.5   4.0  8.40         1
# 11         327          111                  4  4.0   4.5  9.00         1
# ...

# %%
y = data['Chance of Admit '].copy()
#print(y)
#data
# Out:
# 0    0.92
# 1    0.76
# 2    0.72
# 3    0.80
# 4    0.65
# Name: Chance of Admit , dtype: float64

# %%
del data['Chance of Admit ']

# %%
x = data.copy()

# %%
k = DecisionTreeRegressor(max_leaf_nodes=10)
k.fit(x,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=10, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
predictions = k.predict(x)

# %%
error = 0
for i in range(10):
    print(predictions[i],y[i])
# Out:
# 0.934107142857143 0.92
# 0.7738271604938273 0.76
# 0.5826865671641791 0.72
# 0.7277083333333335 0.8
# 0.6455882352941176 0.65
# 0.8797142857142856 0.9
# 0.7277083333333335 0.75
# 0.5826865671641791 0.68
# 0.5826865671641791 0.5
# 0.7277083333333335 0.45

# %%
print(error)
# Out:
# 0.034421525851911106
